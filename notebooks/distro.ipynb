# %%
from pathlib import Path
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from typing import Dict, List, Tuple

# %%
import sys
import os

app = "/app"
if app not in sys.path:
    sys.path.append(app)

# %%
from src.sampler import Sampler
from src.corpus import Corpus
from src.embed import OpenAIEmbedder, SBERTEmbedder, BarlowParagraphEmbedder, BarlowSentenceEmbedder
from src.utils import split_paragraphs, split_sentences
from src.config import config

# %%
config
# Out:
# Config(embedding_model={'openai': 'text-embedding-ada-002', 'sbert': 'all-mpnet-base-v2', 'barlow': '/app/pretrained/twin-lm-checkpoint-32000'}, sections='introduction+results+discussion+methods')

# %%
# import openai
# openai.Model.list()

# %%
# note default model from config.embeeding_models can be overriden by model="blah"
# embedder = SBERTEmbedder()
embedder = OpenAIEmbedder()
# embedder = BarlowParagraphEmbedder(model="/app/pretrained/twin-no-lm-checkpoint-32000")
# embedder = BarlowSentenceEmbedder()
print(embedder.model)
# Out:
# text-embedding-ada-002

# %%
doi_list = [
    '10.1101/2021.05.12.443743',  # 3 reviews
    '10.1101/2022.11.25.517987',  # 2 reviews
    '10.1101/2022.01.04.474903',  # 3 reviews
    '10.1101/2022.09.09.507210',  # 3 reviews
    '10.1101/2022.08.24.504515',
    '10.1101/2022.09.08.507099',
    '10.1101/2022.04.17.488591',
    '10.1101/2022.08.24.505080',
    '10.1101/2021.12.21.473685',
    '10.1101/2021.07.31.454568',
]

# %%
# fist time, download reviews and preprint and save corpus to disk
# corpus = Corpus(doi_list)
# corpus.save('test_corpus')

# %%
# once save, restore from disk
corpus = Corpus().from_dir('test_corpus')

# %%
sampler = Sampler(corpus, embedder, split_paragraphs)

# %%
distro = sampler.sample(n_sample=5)

# %%
null = pd.DataFrame()
null['similarity'] = distro['null']
null['distro'] = 'null'
N_null = null.shape[0]
N_null
# Out:
# 5323

# %%
enriched = pd.DataFrame()
enriched['similarity'] = distro['enriched']
enriched['distro'] = 'enriched'
N_enriched = enriched.shape[0]
N_enriched
# Out:
# 4020

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x=enriched.similarity, histnorm="percent", name="enriched", xbins=go.histogram.XBins(size=0.0025)))
fig.add_trace(go.Histogram(x=null.similarity, histnorm="percent",name="null", xbins=go.histogram.XBins(size=0.0025)))

# Overlay both histograms
fig.update_layout(
    title_text=f"Distribution with {embedder.model}",
    barmode='overlay',
    template="plotly_dark",
)
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.9)
fig.show()
# Out:
# <div>                            <div id="003a8120-36f1-4bfe-8cfd-bf7a4aac6293" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("003a8120-36f1-4bfe-8cfd-bf7a4aac6293")) {                    Plotly.newPlot(                        "003a8120-36f1-4bfe-8cfd-bf7a4aac6293",                        [{"histnorm":"percent","name":"enriched","x":[0.7293253540992737,0.9086822867393494,0.7233934998512268,0.8607499003410339,0.8812423944473267,0.864758312702179,0.7084283828735352,0.7569370269775391,0.8092191219329834,0.7705001831054688,0.757095992565155,0.7503176927566528,0.8694630861282349,0.7489129304885864,0.8577482104301453,0.8365336656570435,0.8343213796615601,0.7122647166252136,0.7791793942451477,0.8266253471374512,0.7867894768714905,0.7916021943092346,0.7279139757156372,0.9114883542060852,0.7255386114120483,0.8588326573371887,0.8781453371047974,0.8468759655952454,0.6909523010253906,0.7576152682304382,0.7950112819671631,0.748339831829071,0.7620545029640198,0.735689103603363,0.9028337597846985,0.7435983419418335,0.8754943609237671,0.887572705745697,0.8638966679573059,0.7122519612312317,0.7729329466819763,0.8133389353752136,0.7629500031471252,0.7758903503417969,0.7128733396530151,0.9160515069961548,0.7335250377655029,0.857234537601471,0.8740003108978271,0.8532367944717407,0.6812211871147156,0.7825861573219299,0.8175156116485596,0.751214861869812,0.7736681699752808,0.7379267811775208,0.9166969656944275,0.7388301491737366,0.8873897790908813,0.8891201615333557,0.8673937320709229,0.6999387145042419,0.7837256193161011,0.8227561116218567,0.7582670450210571,0.7735790610313416,0.7384065389633179,0.8602626323699951,0.8009238839149475,0.866149365901947,0.8218600749969482,0.8134956359863281,0.7040486931800842,0.8352013826370239,0.8052687644958496,0.7797335386276245,0.7985352873802185,0.7380311489105225,0.8654056787490845,0.7847753763198853,0.873308539390564,0.8363704085350037,0.8063156604766846,0.7142729163169861,0.8027433156967163,0.7969322800636292,0.7511460781097412,0.7993766665458679,0.757513701915741,0.8418939709663391,0.7695227265357971,0.8646546006202698,0.8342461585998535,0.8161044120788574,0.7300029993057251,0.7913517951965332,0.8194264769554138,0.7806179523468018,0.8018364310264587,0.7431991696357727,0.8713785409927368,0.7895487546920776,0.8820998072624207,0.8408381938934326,0.8224902153015137,0.7143057584762573,0.8217059969902039,0.805425763130188,0.7729859352111816,0.8234161734580994,0.7377342581748962,0.7980374097824097,0.7744694948196411,0.8032140731811523,0.7791315913200378,0.7554553747177124,0.730780839920044,0.818112313747406,0.8075931072235107,0.8339650630950928,0.8097255229949951,0.7493805885314941,0.8839887380599976,0.7827900648117065,0.8916123509407043,0.8519574403762817,0.8340618014335632,0.7135431170463562,0.8150767087936401,0.8149422407150269,0.7606641054153442,0.798204779624939,0.7459272742271423,0.7934187650680542,0.7625366449356079,0.8187888860702515,0.7891835570335388,0.762902021408081,0.7267249822616577,0.8376431465148926,0.8323720693588257,0.8095468282699585,0.8071475625038147,0.7297884821891785,0.8764625191688538,0.7794831991195679,0.8647128343582153,0.8425120711326599,0.8151707053184509,0.7105674147605896,0.8299376368522644,0.8309927582740784,0.793003261089325,0.7888952493667603,0.750248908996582,0.8704248666763306,0.7592809200286865,0.8746019601821899,0.8539913892745972,0.8365098237991333,0.7077367901802063,0.8285278081893921,0.8461998105049133,0.7854986190795898,0.7863463759422302,0.7366519570350647,0.8555111885070801,0.7889982461929321,0.8579800724983215,0.8298336863517761,0.809422492980957,0.7084305286407471,0.8799394369125366,0.8352263569831848,0.785953938961029,0.7952613830566406,0.750076413154602,0.8725146055221558,0.7454653978347778,0.8548471331596375,0.853515625,0.8376286625 ...

# %%
cutoff_pos = enriched.similarity.quantile(q=0.99)
cutoff_pos
# Out:
# 0.9160430020093918

# %%
cutoff_neg = null.similarity.quantile(q=0.99)
cutoff_neg
# Out:
# 0.8105259239673615
